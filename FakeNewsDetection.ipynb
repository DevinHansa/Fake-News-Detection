# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')

# %%
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
fake['label']=0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'], axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0      0  Donald Trump just couldn t wish all Americans ...      0
# 1      1  House Intelligence Committee Chairman Devin Nu...      0
# 2      2  On Friday, it was revealed that former Milwauk...      0
# 3      3  On Christmas day, Donald Trump announced that ...      0
# 4      4  Pope Francis used his annual Christmas Day mes...      0

# %%
news.drop(['index'], axis=1, inplace=True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
import re

# %%
def wordopt(text):
  text = text.lower()

  text = re.sub(r'https?://\S+|www\.\S+','',text)

  text = re.sub(r'<.*?>','',text)

  text = re.sub(r'[^\w\s]','',text)

  text = re.sub(r'\d','',text)

  text = re.sub(r'\n','',text)

  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        donald trump just couldn t wish all americans ...
# 1        house intelligence committee chairman devin nu...
# 2        on friday it was revealed that former milwauke...
# 3        on christmas day donald trump announced that h...
# 4        pope francis used his annual christmas day mes...
#                                ...
# 44893    brussels reuters  nato allies on tuesday welco...
# 44894    london reuters  lexisnexis a provider of legal...
# 44895    minsk reuters  in the shadow of disused soviet...
# 44896    moscow reuters  vatican secretary of state car...
# 44897    jakarta reuters  indonesia will buy  sukhoi fi...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']

# %%
y = news['label']

# %%
x
# Out:
# 0        donald trump just couldn t wish all americans ...
# 1        house intelligence committee chairman devin nu...
# 2        on friday it was revealed that former milwauke...
# 3        on christmas day donald trump announced that h...
# 4        pope francis used his annual christmas day mes...
#                                ...
# 44893    brussels reuters  nato allies on tuesday welco...
# 44894    london reuters  lexisnexis a provider of legal...
# 44895    minsk reuters  in the shadow of disused soviet...
# 44896    moscow reuters  vatican secretary of state car...
# 44897    jakarta reuters  indonesia will buy  sukhoi fi...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 44893    1
# 44894    1
# 44895    1
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.fit_transform(x_test)

# %%
xv_train
# Out:
# <31428x175515 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6479123 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x109267 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2740032 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize a TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit the vectorizer on the training data and transform it
xv_train = vectorizer.fit_transform(x_train)

# Transform the testing data using the same vectorizer
xv_test = vectorizer.transform(x_test)

# %%
# Make predictions on the testing data
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.987305122494432

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, pred_lr)


print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7006
#            1       0.98      0.99      0.99      6464
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.995916852264291

# %%
pred_dtc = DTC.predict(xv_test)

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7006
#            1       1.00      1.00      1.00      6464
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit = (xv_train, y_train)

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize the RandomForestClassifier
rfc = RandomForestClassifier()

# Train the RandomForestClassifier on the training data
rfc.fit(xv_train, y_train)

# Make predictions on the testing data
predict_rfc = rfc.predict(xv_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_test, predict_rfc)
print("Accuracy:", accuracy)

# Calculate precision
precision = precision_score(y_test, predict_rfc)
print("Precision:", precision)

# Calculate recall
recall = recall_score(y_test, predict_rfc)
print("Recall:", recall)

# Calculate F1-score
f1 = f1_score(y_test, predict_rfc)
print("F1-score:", f1)

# Calculate confusion matrix
cm = confusion_matrix(y_test, predict_rfc)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.9885671863400148
# Precision: 0.9873339511893728
# Recall: 0.9888613861386139
# F1-score: 0.9880970783737827
# Confusion Matrix:
#  [[6924   82]
#  [  72 6392]]

# %%
# !pip install --upgrade scikit-learn

# %%
def output_label(n):
  if n==0:
    return "It is a Fake News"

  elif n==1:
    return "It is Genuine News"

# %%
def manual_testing(news):
    # Define or import preprocess_text function here
    # preprocessed_news = preprocess_text(news)

    # Placeholder for preprocessing
    preprocessed_news = news.lower()  # Example placeholder

    # Vectorize the preprocessed news using the same vectorizer used during training
    xv_manual = vectorizer.transform([preprocessed_news])

    # Make predictions using your trained model
    predicted_label = LR.predict(xv_manual)

    # Map the predicted label to a human-readable output
    return output_label(predicted_label[0])
